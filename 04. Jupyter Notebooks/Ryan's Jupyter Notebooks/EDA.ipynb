# %%
import pandas as pd

# %%
# !rm "../../02. Madison Subset/Madison_Reviews_Exp.csv"

# %%
# !ls "../../02. Madison Subset"
# Out:
# Madison_BusinessIds.csv		  Madison_Reviews.csv
# MadisonRestaurants_CheckIn.csv	  Madison_UserIds_FromTipData.csv
# MadisonRestaurants.csv		  MadisonUsersPartial.csv
# MadisonRestaurants_Tip_Check.csv  MadisonUsersPartial.xlsx
# MadisonRestaurants_Tip.csv

# %%
bdf = pd.read_csv("../../02. Madison Subset/MadisonRestaurants.csv")
rdf = pd.read_csv("../../02. Madison Subset/Madison_Reviews_Exp.csv")

# %%
df = bdf.merge(rdf, on="business_id")

# %%
df.head()
# Out:
#    Unnamed: 0_x             business_id      name       address     city  \
# 0           387  1BQzXcXFxR6MlVIYmG93kw  Zandru's  419 State St  Madison
# 1           387  1BQzXcXFxR6MlVIYmG93kw  Zandru's  419 State St  Madison
# 2           387  1BQzXcXFxR6MlVIYmG93kw  Zandru's  419 State St  Madison
# 3           387  1BQzXcXFxR6MlVIYmG93kw  Zandru's  419 State St  Madison
# 4           387  1BQzXcXFxR6MlVIYmG93kw  Zandru's  419 State St  Madison
#
#   state  postal_code   latitude  longitude  stars_x  ...  funny  useful  \
# 0    WI      53703.0  43.074724 -89.392598      3.5  ...      0       1
# 1    WI      53703.0  43.074724 -89.392598      3.5  ...      0       0
# 2    WI      53703.0  43.074724 -89.392598      3.5  ...      3       7
# 3    WI      53703.0  43.074724 -89.392598      3.5  ...      0       0
# 4    WI      53703.0  43.074724 -89.392598      3.5  ...      0       1
#
#                 review_id                                               text  \
# 0  M55Dbvn7123F1eTxe1b7-Q  So far not impressed. Here for a bachelorette ...
# 1  cOeYP-7lY2Kb_0MgUYO4Kg  Delicious, authentic Spanish food!  Friendly s...
# 2  YVs9P-DoILfXq08UKwOaxA  With only one review in for the new Zandru's, ...
# 3  RtIHX4mGwBPnJc8mC8wPtA  Great drinks! We just got the Spanish combinat...
# 4  c15Uor559lavT8N13NQLDw  I literally made this yelp account to warn eve...
#
#   stars_y                 date                 user_id  cool  \
# 0     1.0  2017-05-13 23:30:46  3tco9dK9yCqsNk6olGqkqw     0
# 1     5.0  2017-08-17 00:05:49  2m-KLSt4yC3zTTBcyv46Tw     0
# 2     2.0  2017-04-20 14:40:55  8teQ4Zc9jpl_ffaPJUn6Ew     1
# 3     5.0  2017-10-04 16:40:30  tm9jucB14wjhZZ00dNdsuQ     0
# 4     1.0  2017-05-17 01:11:03  9Q45WYIP-ZHOVAZpYGFVpA     0
#
#               datetime  yelp_lifetime
# 0  2017-05-13 23:30:46       0.649315
# 1  2017-08-17 00:05:49       0.649315
# 2  2017-04-20 14:40:55       0.649315
# 3  2017-10-04 16:40:30       0.649315
# 4  2017-05-17 01:11:03       0.649315
#
# [5 rows x 29 columns]
